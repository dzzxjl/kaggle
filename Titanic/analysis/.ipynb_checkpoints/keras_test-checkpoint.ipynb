# %%
# Import all the libraries I need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

from sklearn.ensemble import RandomForestRegressor
#from sklearn.ensemble import RandomForestClassifier
#from xgboost import XGBClassifier
#from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import GridSearchCV

import keras 
from keras.models import Sequential # intitialize the ANN
from keras.layers import Dense      # create layers

# load the data
path1 = '/Users/dzzxjl/PycharmProjects/tianchi/titanic_test/input/train.csv'
path2 = '/Users/dzzxjl/PycharmProjects/tianchi/titanic_test/input/test.csv'
df_train = pd.read_csv(path1)
df_test = pd.read_csv(path2)
df = df_train.append(df_test , ignore_index = True)
df.info()
print(df.info())
df.describe()
# Out:
# Using TensorFlow backend.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB
# None
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived
# count  1309.000000  891.000000
# mean      0.498854    0.383838
# std       1.041658    0.486592
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %%
df_train.shape, df_test.shape, df_train.columns.values
# Out:
# ((891, 12),
#  (418, 11),
#  array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object))

# %%
df['Pclass'].isnull().sum(axis=0)
# Out:
# 0

# %%
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).sum()
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df.Name.head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Title'] = df.Name.map(lambda x : x.split(',')[1].split('.')[0].strip())

# %%
df.Title.value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Dr                8
# Rev               8
# Col               4
# Ms                2
# Mlle              2
# Major             2
# Jonkheer          1
# the Countess      1
# Capt              1
# Sir               1
# Mme               1
# Lady              1
# Dona              1
# Don               1
# Name: Title, dtype: int64

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace(['Mme','Lady','Ms'], 'Mrs')
df.Title.loc[ (df.Title !=  'Master') & (df.Title !=  'Mr') & (df.Title !=  'Miss') 
             & (df.Title !=  'Mrs')] = 'Others'
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.701087
# 2      Mr  0.156673
# 3     Mrs  0.796875
# 4  Others  0.318182

# %%
df.Title.value_counts()
# Out:
# Mr        757
# Miss      262
# Mrs       201
# Master     61
# Others     28
# Name: Title, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(df['Title'])], axis=1).drop(labels=['Name'], axis=1)

# %%
df
# Out:
#        Age        Cabin Embarked      Fare  Parch  PassengerId  Pclass  \
# 0     22.0          NaN        S    7.2500      0            1       3
# 1     38.0          C85        C   71.2833      0            2       1
# 2     26.0          NaN        S    7.9250      0            3       3
# 3     35.0         C123        S   53.1000      0            4       1
# 4     35.0          NaN        S    8.0500      0            5       3
# 5      NaN          NaN        Q    8.4583      0            6       3
# 6     54.0          E46        S   51.8625      0            7       1
# 7      2.0          NaN        S   21.0750      1            8       3
# 8     27.0          NaN        S   11.1333      2            9       3
# 9     14.0          NaN        C   30.0708      0           10       2
# 10     4.0           G6        S   16.7000      1           11       3
# 11    58.0         C103        S   26.5500      0           12       1
# 12    20.0          NaN        S    8.0500      0           13       3
# 13    39.0          NaN        S   31.2750      5           14       3
# 14    14.0          NaN        S    7.8542      0           15       3
# 15    55.0          NaN        S   16.0000      0           16       2
# 16     2.0          NaN        Q   29.1250      1           17       3
# 17     NaN          NaN        S   13.0000      0           18       2
# 18    31.0          NaN        S   18.0000      0           19       3
# 19     NaN          NaN        C    7.2250      0           20       3
# 20    35.0          NaN        S   26.0000      0           21       2
# 21    34.0          D56        S   13.0000      0           22       2
# 22    15.0          NaN        Q    8.0292      0           23       3
# 23    28.0           A6        S   35.5000      0           24       1
# 24     8.0          NaN        S   21.0750      1           25       3
# 25    38.0          NaN        S   31.3875      5           26       3
# 26     NaN          NaN        C    7.2250      0           27       3
# 27    19.0  C23 C25 C27        S  263.0000      2           28       1
# 28     NaN          NaN        Q    7.8792      0           29       3
# 29     NaN          NaN        S    7.8958      0           30       3
# ...    ...          ...      ...       ...    ...          ...     ...
# 1279  21.0          NaN        Q    7.7500      0         1280       3
# %%
df.Sex.isnull().sum(axis=0)
# Out:
# 0

# %%
df[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df.Sex = df.Sex.map({'male':0, 'female':1})

# %%
df.Sex
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       1
# 10      1
# 11      1
# 12      0
# 13      0
# 14      1
# 15      1
# 16      0
# 17      0
# 18      1
# 19      1
# 20      0
# 21      0
# 22      1
# 23      0
# 24      1
# 25      1
# 26      0
# 27      0
# 28      1
# 29      0
#        ..
# 1279    0
# 1280    0
# 1281    0
# 1282    1
# 1283    0
# 1284    0
# 1285    0
# 1286    1
# 1287    0
# 1288    1
# 1289    0
# 1290    0
# 1291    1
# 1292    0
# 1293    1
# 1294    0
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    1
# 1300    1
# 1301    1
# 1302    1
# 1303    1
# 1304    0
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: Sex, Length: 1309, dtype: int64

# %%
df.Age.isnull().sum(axis=0)
# Out:
# 263

# %%
df.SibSp.isnull().sum(axis=0), df.Parch.isnull().sum(axis=0)
# Out:
# (0, 0)

# %%
df.columns.values
# Out:
# array(['Age', 'Cabin', 'Embarked', 'Fare', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Title', 'Master',
#        'Miss', 'Mr', 'Mrs', 'Others'], dtype=object)

# %%
df['Family'] = df['SibSp'] + df['Parch'] + 1

# %%
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       1  0.303538
# 1       2  0.552795
# 2       3  0.578431
# 3       4  0.724138
# 4       5  0.200000
# 5       6  0.136364
# 6       7  0.333333
# 7       8  0.000000
# 8      11  0.000000

# %%
df.Family = df.Family.map(lambda x : 0 if x > 4 else x)

# %%
df.Family.value_counts()
# Out:
# 1    790
# 2    235
# 3    159
# 0     82
# 4     43
# Name: Family, dtype: int64

# %%
df.Ticket.isnull().sum(axis=0)
# Out:
# 0

# %%
df.Ticket.head(10)
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# 5              330877
# 6               17463
# 7              349909
# 8              347742
# 9              237736
# Name: Ticket, dtype: object

# %%
df.Ticket = df.Ticket.map(lambda x: x[0])

# inspect the correlation between Ticket and Survived
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# S     98
# P     98
# C     77
# A     42
# W     19
# 7     13
# F     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %%
df[['Ticket', 'Fare']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket        Fare
# 0       1   65.771211
# 1       2   20.235194
# 2       3   15.380682
# 3       4   16.764036
# 4       5   19.262500
# 5       6   19.153711
# 6       7    9.197438
# 7       8    8.397900
# 8       9    7.750000
# 9       A   10.189681
# 10      C   28.152273
# 11      F   24.677246
# 12      L    1.515000
# 13      P  119.698253
# 14      S   17.542900
# 15      W   31.056579

# %%
# check if there is any NAN
df.Fare.isnull().sum(axis=0)
df.Ticket[df.Fare.isnull()]
df.Pclass[df.Fare.isnull()]
df.Cabin[df.Fare.isnull()]
df.Embarked[df.Fare.isnull()]
# Out:
# 1043    S
# Name: Embarked, dtype: object

# %%
df
# Out:
#        Age        Cabin Embarked      Fare  Parch  PassengerId  Pclass  Sex  \
# 0     22.0          NaN        S    7.2500      0            1       3    0
# 1     38.0          C85        C   71.2833      0            2       1    1
# 2     26.0          NaN        S    7.9250      0            3       3    1
# 3     35.0         C123        S   53.1000      0            4       1    1
# 4     35.0          NaN        S    8.0500      0            5       3    0
# 5      NaN          NaN        Q    8.4583      0            6       3    0
# 6     54.0          E46        S   51.8625      0            7       1    0
# 7      2.0          NaN        S   21.0750      1            8       3    0
# 8     27.0          NaN        S   11.1333      2            9       3    1
# 9     14.0          NaN        C   30.0708      0           10       2    1
# 10     4.0           G6        S   16.7000      1           11       3    1
# 11    58.0         C103        S   26.5500      0           12       1    1
# 12    20.0          NaN        S    8.0500      0           13       3    0
# 13    39.0          NaN        S   31.2750      5           14       3    0
# 14    14.0          NaN        S    7.8542      0           15       3    1
# 15    55.0          NaN        S   16.0000      0           16       2    1
# 16     2.0          NaN        Q   29.1250      1           17       3    0
# 17     NaN          NaN        S   13.0000      0           18       2    0
# 18    31.0          NaN        S   18.0000      0           19       3    1
# 19     NaN          NaN        C    7.2250      0           20       3    1
# 20    35.0          NaN        S   26.0000      0           21       2    0
# 21    34.0          D56        S   13.0000      0           22       2    0
# 22    15.0          NaN        Q    8.0292      0           23       3    1
# 23    28.0           A6        S   35.5000      0           24       1    0
# 24     8.0          NaN        S   21.0750      1           25       3    1
# 25    38.0          NaN        S   31.3875      5           26       3    1
# 26     NaN          NaN        C    7.2250      0           27       3    0
# 27    19.0  C23 C25 C27        S  263.0000      2           28       1    0
# 28     NaN          NaN        Q    7.8792      0           29       3    1
# 29     NaN          NaN        S    7.8958      0           30       3    0
# ...    ...          ...      ...       ...    ...          ...     ...  ...
# 1279  21.0          NaN        Q    7.7500      0         1280       3    0
# 1280   6.0          NaN        S   21.0750      1         1281       3    0
# 1281  23.0          B24        S   93.5000      0         1282       1    0
# 1282  51.0          D28        S   39.4000      1         1283       1    1
# 1283  13.0          NaN        S   20.2500      2         1284       3    0
# 1284  47.0          NaN        S   10.5000      0         1285       2    0
# 1285  29.0          NaN        S   22.0250      1         1286       3    0
# 1286  18.0          C31        S   60.0000      0         1287       1    1
# 1287  24.0          NaN        Q    7.2500      0         1288       3    0
# 1288  48.0          B41        C   79.2000      1         1289       1    1
# 1289  22.0          NaN        S    7.7750      0         1290       3    0
# 1290  31.0          NaN        Q    7.7333      0         1291       3    0
# 1291  30.0           C7        S  164.8667      0         1292       1    1
# 1292  38.0          NaN        S   21.0000      0         1293       2    0
# 1293  22.0          NaN        C   59.4000      1         1294       1    1
# 1294  17.0          NaN        S   47.1000      0         1295       1    0
# 1295  43.0          D40        C   27.7208      0         1296       1    0
# 1296  20.0          D38        C   13.8625      0         1297       2    0
# 1297  23.0          NaN        S   10.5000      0         1298       2    0
# 1298  50.0          C80        C  211.5000      1         1299       1    0
# 1299   NaN          NaN        Q    7.7208      0         1300       3    1
# 1300   3.0          NaN        S   13.7750      1         1301       3    1
# 1301   NaN          NaN        Q    7.7500      0         1302       3    1
# 1302  37.0          C78        Q   90.0000      0         1303       1    1
# 1303  28.0          NaN        S    7.7750      0         1304       3    1
# 1304   NaN          NaN        S    8.0500      0         1305       3    0
# 1305  39.0         C105        C  108.9000      0         1306       1    1
# 1306  38.5          NaN        S    7.2500      0         1307       3    0
# 1307   NaN          NaN        S    8.0500      0         1308       3    0
# 1308   NaN          NaN        C   22.3583      1         1309       3    0
#
#       SibSp  Survived Ticket   Title  Master  Miss  Mr  Mrs  Others  Family
# 0         1       0.0      A      Mr       0     0   1    0       0       2
# 1         1       1.0      P     Mrs       0     0   0    1       0       2
# 2         0       1.0      S    Miss       0     1   0    0       0       1
# 3         1       1.0      1     Mrs       0     0   0    1       0       2
# 4         0       0.0      3      Mr       0     0   1    0       0       1
# 5         0       0.0      3      Mr       0     0   1    0       0       1
# 6         0       0.0      1      Mr       0     0   1    0       0       1
# 7         3       0.0      3  Master       1     0   0    0       0       0
# 8         0       1.0      3     Mrs       0     0   0    1       0       3
# 9         1       1.0      2     Mrs       0     0   0    1       0       2
# 10        1       1.0      P    Miss       0     1   0    0       0       3
# 11        0       1.0      1    Miss       0     1   0    0       0       1
# 12        0       0.0      A      Mr       0     0   1    0       0       1
# 13        1       0.0      3      Mr       0     0   1    0       0       0
# 14        0       0.0      3    Miss       0     1   0    0       0       1
# 15        0       1.0      2     Mrs       0     0   0    1       0       1
# 16        4       0.0      3  Master       1     0   0    0       0       0
# 17        0       1.0      2      Mr       0     0   1    0       0       1
# 18        1       0.0      3     Mrs       0     0   0    1       0       2
# 19        0       1.0      2     Mrs       0     0   0    1       0       1
# 20        0       0.0      2      Mr       0     0   1    0       0       1
# 21        0       1.0      2      Mr       0     0   1    0       0       1
# 22        0       1.0      3    Miss       0     1   0    0       0       1
# 23        0       1.0      1      Mr       0     0   1    0       0       1
# 24        3       0.0      3    Miss       0     1   0    0       0       0
# 25        1       1.0      3     Mrs       0     0   0    1       0       0
# 26        0       0.0      2      Mr       0     0   1    0       0       1
# 27        3       0.0      1      Mr       0     0   1    0       0       0
# 28        0       1.0      3    Miss       0     1   0    0       0       1
# 29        0       0.0      3      Mr       0     0   1    0       0       1
# ...     ...       ...    ...     ...     ...   ...  ..  ...     ...     ...
# 1279      0       NaN      3      Mr       0     0   1    0       0       1
# 1280      3       NaN      3  Master       1     0   0    0       0       0
# 1281      0       NaN      1      Mr       0     0   1    0       0       1
# 1282      0       NaN      P     Mrs       0     0   0    1       0       2
# 1283      0       NaN      C  Master       1     0   0    0       0       3
# 1284      0       NaN      C      Mr       0     0   1    0       0       1
# 1285      3       NaN      3      Mr       0     0   1    0       0       0
# 1286      1       NaN      1     Mrs       0     0   0    1       0       2
# 1287      0       NaN      3      Mr       0     0   1    0       0       1
# 1288      1       NaN      1     Mrs       0     0   0    1       0       3
# 1289      0       NaN      3      Mr       0     0   1    0       0       1
# 1290      0       NaN      2      Mr       0     0   1    0       0       1
# 1291      0       NaN      3    Miss       0     1   0    0       0       1
# 1292      1       NaN      2      Mr       0     0   1    0       0       2
# 1293      0       NaN      1    Miss       0     1   0    0       0       2
# 1294      0       NaN      1      Mr       0     0   1    0       0       1
# 1295      1       NaN      1      Mr       0     0   1    0       0       2
# 1296      0       NaN      S      Mr       0     0   1    0       0       1
# 1297      1       NaN      2      Mr       0     0   1    0       0       2
# 1298      1       NaN      1      Mr       0     0   1    0       0       3
# 1299      0       NaN      3    Miss       0     1   0    0       0       1
# 1300      1       NaN      S    Miss       0     1   0    0       0       3
# 1301      0       NaN      3    Miss       0     1   0    0       0       1
# 1302      1       NaN      1     Mrs       0     0   0    1       0       2
# 1303      0       NaN      3    Miss       0     1   0    0       0       1
# 1304      0       NaN      A      Mr       0     0   1    0       0       1
# 1305      0       NaN      P  Others       0     0   0    0       1       1
# 1306      0       NaN      S      Mr       0     0   1    0       0       1
# 1307      0       NaN      3      Mr       0     0   1    0       0       1
# 1308      1       NaN      2  Master       1     0   0    0       0       3
#
# [1309 rows x 18 columns]

# %%
# use boxplot to visualize the distribution of Fare for each Pclass
sns.boxplot('Pclass','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show(block=False)

# %%
df.columns.values
# Out:
# array(['Age', 'Cabin', 'Embarked', 'Fare', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Title', 'Master',
#        'Miss', 'Mr', 'Mrs', 'Others', 'Family'], dtype=object)

# %%
df[['Pclass', 'Fare']].groupby(['Pclass'], as_index=0).mean()
# Out:
#    Pclass       Fare
# 0       1  87.508992
# 1       2  21.179196
# 2       3  13.302889

# %%
df[['Pclass', 'Fare']].groupby(['Pclass']).std() / df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#             Fare
# Pclass
# 1       0.919302
# 2       0.642476
# 3       0.864050

# %%
sns.boxplot('Ticket', 'Fare', data=df)
plt.ylim(0, 300)
plt.show()
