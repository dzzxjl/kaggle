# %%
path1 = '/Users/dzzxjl/PycharmProjects/tianchi/house_price/input/train.csv'
path2 = '/Users/dzzxjl/PycharmProjects/tianchi/house_price/input/test.csv'
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:01.209980. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df = pd.read_csv(path1)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:01.663507. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df[:10]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 5         Lvl    AllPub    ...            0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 7         Lvl    AllPub    ...            0    NaN    NaN        Shed     350
# 8         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 9         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:02.617970. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:03.277603. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:03.867795. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
corr = df.select_dtypes(include=['float64', 'int64']).iloc[:, 1:].corr()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:32:04.418886. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plt.figure(figsize=(12, 6))
# sns.heatmap(corr, vmax=1, square=True)
sns.heatmap(corr, vmax=1, square=True)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:33:58.711800. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
cor_dict = corr['SalePrice'].to_dict()
del corr['SalePrice']
cor_dict
# Out:
# {'1stFlrSF': 0.6058521846919166,
#  '2ndFlrSF': 0.31933380283206614,
#  '3SsnPorch': 0.044583665335747917,
#  'BedroomAbvGr': 0.16821315430074149,
#  'BsmtFinSF1': 0.38641980624215627,
#  'BsmtFinSF2': -0.011378121450215216,
#  'BsmtFullBath': 0.22712223313149718,
#  'BsmtHalfBath': -0.016844154297359294,
#  'BsmtUnfSF': 0.214479105546969,
#  'EnclosedPorch': -0.12857795792595636,
#  'Fireplaces': 0.46692883675152419,
#  'FullBath': 0.5606637627484452,
#  'GarageArea': 0.62343143891835984,
#  'GarageCars': 0.64040919725834899,
#  'GarageYrBlt': 0.48636167748786213,
#  'GrLivArea': 0.70862447761265113,
#  'HalfBath': 0.2841076755947784,
#  'KitchenAbvGr': -0.13590737084214169,
#  'LotArea': 0.26384335387140628,
#  'LotFrontage': 0.35179909657067854,
#  'LowQualFinSF': -0.025606130000680152,
#  'MSSubClass': -0.08428413512659523,
#  'MasVnrArea': 0.47749304709571072,
#  'MiscVal': -0.021189579640303789,
#  'MoSold': 0.046432245223819363,
#  'OpenPorchSF': 0.31585622711605577,
#  'OverallCond': -0.077855894048677599,
#  'OverallQual': 0.79098160058380473,
#  'PoolArea': 0.09240354949187278,
#  'SalePrice': 1.0,
#  'ScreenPorch': 0.11144657114291048,
#  'TotRmsAbvGrd': 0.53372315558202377,
#  'TotalBsmtSF': 0.61358055155919444,
#  'WoodDeckSF': 0.32441344456813076,
#  'YearBuilt': 0.52289733287949669,
#  'YearRemodAdd': 0.50710096711138675,
#  'YrSold': -0.028922585168730426}
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:35:38.893386. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
sns.regplot(x = 'OverallQual', y = 'SalePrice', data=df, color='Red')
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 16:38:17.987979. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plt.figure(1)
f, axarr = plt.subplots(3, 2, figsize=(10, 9))
price = df.SalePrice.values
axarr[0, 0].scatter(df.GrLivArea.values, price)
axarr[0, 0].set_title('GrLivArea')
axarr[0, 1].scatter(df.GarageArea.values, price)
axarr[0, 1].set_title('GarageArea')
axarr[1, 0].scatter(df.TotalBsmtSF.values, price)
axarr[1, 0].set_title('TotalBsmtSF')
axarr[1, 1].scatter(df['1stFlrSF'].values, price)
axarr[1, 1].set_title('1stFlrSF')
axarr[2, 0].scatter(df.TotRmsAbvGrd.values, price)
axarr[2, 0].set_title('TotRmsAbvGrd')
axarr[2, 1].scatter(df.MasVnrArea.values, price)
axarr[2, 1].set_title('MasVnrArea')
f.text(-0.01, 0.5, 'Sale Price', va='center', rotation='vertical', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 17:01:11.294476. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
fig = plt.figure(2, figsize=(9, 7))
plt.subplot(211)
plt.scatter(df.YearBuilt.values, price)
plt.title('YearBuilt')

plt.subplot(212)
plt.scatter(df.YearRemodAdd.values, price)
plt.title('YearRemodAdd')

fig.text(-0.01, 0.5, 'Sale Price', va = 'center', rotation = 'vertical', fontsize = 12)

plt.tight_layout()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 17:04:34.232220. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
df[['Neighborhood','SalePrice']]
# Out:
#      Neighborhood  SalePrice
# 0         CollgCr     208500
# 1         Veenker     181500
# 2         CollgCr     223500
# 3         Crawfor     140000
# 4         NoRidge     250000
# 5         Mitchel     143000
# 6         Somerst     307000
# 7          NWAmes     200000
# 8         OldTown     129900
# 9         BrkSide     118000
# 10         Sawyer     129500
# 11        NridgHt     345000
# 12         Sawyer     144000
# 13        CollgCr     279500
# 14          NAmes     157000
# 15        BrkSide     132000
# 16          NAmes     149000
# 17         Sawyer      90000
# 18        SawyerW     159000
# 19          NAmes     139000
# 20        NridgHt     325300
# 21         IDOTRR     139400
# 22        CollgCr     230000
# 23        MeadowV     129900
# 24         Sawyer     154000
# 25        NridgHt     256300
# 26          NAmes     134800
# 27        NridgHt     306000
# 28          NAmes     207500
# 29        BrkSide      68500
# 30         IDOTRR      40000
# 31         Sawyer     149350
# 32        CollgCr     179900
# 33          NAmes     165500
# 34        NridgHt     277500
# 35        NridgHt     309000
# 36        CollgCr     145000
# 37          NAmes     153000
# 38          NAmes     109000
# 39        Edwards      82000
# 40          NAmes     160000
# 41         Timber     170000
# 42        SawyerW     144000
# 43        CollgCr     130250
# 44          NAmes     141000
# 45        NridgHt     319900
# 46        Mitchel     239686
# 47        Somerst     249700
# 48        OldTown     113000
# 49         Sawyer     127000
# 50        Gilbert     177000
# 51        BrkSide     114500
# 52         IDOTRR     110000
# 53        Veenker     385000
# 54          NAmes     130000
# 55          NAmes     180500
# 56        Somerst     172500
# 57        CollgCr     196500
# 58        StoneBr     438780
# 59        CollgCr     124900
# 60        SawyerW     158000
# 61         IDOTRR     101000
# 62        NridgHt     202500
# 63        OldTown     140000
# 64        CollgCr     219500
# 65        NridgHt     317000
# 66          NAmes     180000
# 67        CollgCr     226000
# 68        OldTown      80000
# 69        ClearCr     225000
# 70          NAmes     244000
# 71        Mitchel     129500
# 72        Gilbert     185000
# 73          NAmes     144900
# 74        OldTown     107400
# 75        MeadowV      91000
# 76          NAmes     135750
# 77        BrkSide     127000
# 78         Sawyer     136500
# 79        OldTown     110000
# 80          NAmes     193500
# 81        Mitchel     153500
# 82        Somerst     245000
# 83          NAmes     126500
# 84        Gilbert     168500
# 85        NoRidge     260000
# 86        Gilbert     174000
# 87        Somerst     164500
# 88         IDOTRR      85000
# 89        CollgCr     123600
# 90          NAmes     109900
# 91          NAmes      98600
# 92        Crawfor     163500
# 93        OldTown     133900
# 94        CollgCr     204750
# 95        Gilbert     185000
# 96        CollgCr     214000
# 97        Edwards      94750
# 98        Edwards      83000
# 99          NAmes     128950
# 100        NWAmes     205000
# 101       SawyerW     178000
# 102       SawyerW     118964
# 103       CollgCr     198900
# 104        IDOTRR     169500
# 105       Somerst     250000
# 106       OldTown     100000
# 107       OldTown     115000
# 108        IDOTRR     115000
# 109        NWAmes     190000
# 110       Edwards     136900
# 111       Gilbert     180000
# 112       CollgCr     383970
# 113       Crawfor     217000
# 114       Crawfor     259500
# 115       Somerst     176000
# 116        Sawyer     139000
# 117       Edwards     155000
# 118       SawyerW     320000
# 119       CollgCr     163990
# 120       ClearCr     180000
# 121        IDOTRR     100000
# 122         NAmes     136000
# 123       SawyerW     153900
# 124        NWAmes     181000
# 125        IDOTRR      84500
# 126       NPkVill     128000
# 127       OldTown      87000
# 128         NAmes     155000
# 129         NAmes     150000
# 130         NAmes     226000
# 131       Gilbert     244000
# 132         NAmes     150750
# 133        Timber     220000
# 134        Sawyer     180000
# 135        NWAmes     174000
# 136         NAmes     143000
# 137       Mitchel     171000
# 138       CollgCr     230000
# 139       CollgCr     231500
# 140         NAmes     115000
# 141       CollgCr     260000
# 142         NAmes     166000
# 143       CollgCr     204000
# 144        Sawyer     125000
# 145       Edwards     130000
# 146       BrkSide     105000
# 147       Gilbert     222500
# 148       SawyerW     141000
# 149       BrkSide     115000
# 150       CollgCr     122000
# 151       NridgHt     372402
# 152        NWAmes     190000
# 153       ClearCr     235000
# 154       OldTown     125000
# 155       Edwards      79000
# 156         NAmes     109500
# 157        Timber     269500
# 158       Somerst     254900
# 159       Gilbert     320000
# 160       Veenker     162500
# 161       NridgHt     412500
# 162       NridgHt     220000
# 163       OldTown     103200
# 164       OldTown     152000
# 165       Edwards     127500
# 166       ClearCr     190000
# 167       NridgHt     325624
# 168       Gilbert     183500
# 169        Timber     228000
# 170       OldTown     128500
# 171         NAmes     215000
# 172       StoneBr     239000
# 173         NAmes     163000
# 174        Timber     184000
# 175       Edwards     243000
# 176       ClearCr     211000
# 177        Sawyer     172500
# 178       StoneBr     501837
# 179       OldTown     100000
# 180       Somerst     177000
# 181       Crawfor     200100
# 182       Edwards     120000
# 183       OldTown     200000
# 184       BrkSide     127000
# 185       OldTown     475000
# 186       Mitchel     173000
# 187       OldTown     135000
# 188       SawyerW     153337
# 189       StoneBr     286000
# 190       Crawfor     315000
# 191         NAmes     184000
# 192       CollgCr     192000
# 193       Edwards     130000
# 194       CollgCr     127000
# 195       NPkVill     148500
# 196       Somerst     311872
# 197         NAmes     235000
# 198       OldTown     104000
# 199       NridgHt     274900
# 200       Edwards     140000
# 201       Mitchel     171500
# 202       OldTown     112000
# 203       CollgCr     149000
# 204       OldTown     110000
# 205       Gilbert     180500
# 206        Sawyer     143900
# 207         NAmes     141000
# 208       SawyerW     277000
# 209         NAmes     145000
# 210       Edwards      98000
# 211       Edwards     186000
# 212       Somerst     252678
# 213       CollgCr     156000
# 214       CollgCr     161750
# 215         NAmes     134450
# 216       CollgCr     210000
# 217       OldTown     107000
# 218       Crawfor     311500
# 219       Blmngtn     167240
# 220       CollgCr     204900
# 221       Gilbert     200000
# 222        NWAmes     179900
# 223         NAmes      97000
# 224       NridgHt     386250
# 225        BrDale     112000
# 226       NoRidge     290000
# 227        BrDale     106000
# 228        Sawyer     125000
# 229       Blmngtn     192500
# 230         NAmes     148000
# 231       NoRidge     403000
# 232        BrDale      94500
# 233       CollgCr     128200
# 234       Gilbert     216500
# 235        BrDale      89500
# 236       CollgCr     185500
# 237       SawyerW     194500
# 238       NridgHt     318000
# 239       Edwards     113000
# 240       Somerst     262500
# 241       OldTown     110500
# 242       OldTown      79000
# 243       SawyerW     120000
# 244       SawyerW     205000
# 245        NWAmes     241500
# 246       OldTown     137000
# 247         NAmes     140000
# 248       CollgCr     180000
# 249       ClearCr     277000
# 250       BrkSide      76500
# 251       Crawfor     235000
# 252       SawyerW     173000
# 253         NAmes     158000
# 254         NAmes     145000
# 255       Gilbert     230000
# 256       Somerst     207500
# 257       CollgCr     220000
# 258       CollgCr     231500
# 259       OldTown      97000
# 260         NAmes     176000
# 261       CollgCr     276000
# 262        Sawyer     151000
# 263       OldTown     130000
# 264       OldTown      73000
# 265        NWAmes     175500
# 266       Gilbert     185000
# 267         SWISU     179500
# 268        IDOTRR     120500
# 269       Edwards     148000
# 270       Somerst     266000
# 271       ClearCr     241500
# 272       NoRidge     290000
# 273         NAmes     139000
# 274       Mitchel     124500
# 275       BrkSide     205000
# 276       Mitchel     201000
# 277       Gilbert     141000
# 278       NridgHt     415298
# 279       ClearCr     192000
# 280       SawyerW     228500
# 281       Somerst     185000
# 282       NridgHt     207500
# 283       Somerst     244600
# 284       SawyerW     179200
# 285       Somerst     164700
# 286         NAmes     159000
# 287         NAmes      88000
# 288        Sawyer     122000
# 289       BrkSide     153575
# 290       CollgCr     233230
# 291         SWISU     135900
# 292       Edwards     131000
# 293        NWAmes     235000
# 294         NAmes     167000
# 295       Mitchel     142500
# 296        IDOTRR     152000
# 297       Somerst     239000
# 298        NWAmes     175000
# 299       Crawfor     158500
# 300       Crawfor     157000
# 301       CollgCr     267000
# 302       CollgCr     205000
# 303       CollgCr     149900
# 304       OldTown     295000
# 305       CollgCr     305900
# 306       SawyerW     225000
# 307        IDOTRR      89500
# 308       Edwards      82500
# 309       NridgHt     360000
# 310       Gilbert     165600
# 311         NAmes     132000
# 312       OldTown     119900
# 313        Timber     375000
# 314       OldTown     178000
# 315       Gilbert     188500
# 316        NWAmes     260000
# 317       Somerst     270000
# 318       NoRidge     260000
# 319        NWAmes     187500
# 320       NridgHt     342643
# 321       NridgHt     354000
# 322       SawyerW     301000
# 323       OldTown     126175
# 324         NAmes     242000
# 325        IDOTRR      87000
# 326       Veenker     324000
# 327         NAmes     145250
# 328       BrkSide     214500
# 329        IDOTRR      78000
# 330         NAmes     119000
# 331         NAmes     139000
# 332       NridgHt     284000
# 333       NridgHt     207000
# 334       Gilbert     192000
# 335        Timber     228950
# 336       StoneBr     377426
# 337       CollgCr     214000
# 338        NWAmes     202500
# 339         NAmes     155000
# 340        Timber     202900
# 341       SawyerW      82000
# 342         NAmes      87500
# 343       NridgHt     266000
# 344       MeadowV      85000
# 345       BrkSide     140200
# 346         NAmes     151500
# 347         NAmes     157500
# 348       NridgHt     154000
# 349       NridgHt     437154
# 350       NridgHt     318061
# 351       ClearCr     190000
# 352       Edwards      95000
# 353       OldTown     105900
# 354         SWISU     140000
# 355       CollgCr     177500
# 356       Gilbert     173000
# 357       MeadowV     134000
# 358       ClearCr     130000
# 359       NoRidge     280000
# 360       Mitchel     156000
# 361       BrkSide     145000
# 362       Edwards     198500
# 363        BrDale     118000
# 364        NWAmes     190000
# 365        IDOTRR     147000
# 366         NAmes     159000
# 367         NAmes     165000
# 368         NAmes     132000
# 369         NAmes     162000
# 370       Gilbert     172400
# 371       ClearCr     134432
# 372       SawyerW     125000
# 373         NAmes     123000
# 374       CollgCr     219500
# 375       Edwards      61000
# 376       CollgCr     148000
# 377       Somerst     340000
# 378       StoneBr     394432
# 379       Gilbert     179000
# 380         SWISU     127000
# 381       Somerst     187750
# 382       CollgCr     213500
# 383       SawyerW      76000
# 384       ClearCr     240000
# 385       Blmngtn     192000
# 386       Edwards      81000
# 387       Edwards     125000
# 388       CollgCr     191000
# 389       NridgHt     426000
# 390       Edwards     119000
# 391       Mitchel     215000
# 392         NAmes     106500
# 393       BrkSide     100000
# 394       OldTown     109000
# 395       Edwards     129000
# 396       CollgCr     123000
# 397         NAmes     169500
# 398        IDOTRR      67000
# 399       Somerst     241000
# 400       Veenker     245500
# 401       CollgCr     164990
# 402        Sawyer     108000
# 403       NoRidge     258000
# 404       Gilbert     168000
# 405        Sawyer     150000
# 406         SWISU     115000
# 407       Crawfor     177000
# 408       NridgHt     280000
# 409       Somerst     339750
# 410       Edwards      60000
# 411       Gilbert     145000
# 412       Somerst     222000
# 413       OldTown     115000
# 414       SawyerW     228000
# 415       Gilbert     181134
# 416        Sawyer     149500
# 417       Crawfor     239000
# 418       Edwards     126000
# 419         NAmes     142000
# 420       Mitchel     206300
# 421        NWAmes     215000
# 422       Mitchel     113000
# 423       NoRidge     315000
# 424         NAmes     139000
# 425       OldTown     135000
# 426       SawyerW     275000
# 427         NAmes     109008
# 428       CollgCr     195400
# 429        Timber     175000
# 430        BrDale      85400
# 431       OldTown      79900
# 432        BrDale     122500
# 433       Gilbert     181000
# 434       MeadowV      81000
# 435       CollgCr     212000
# 436       OldTown     116000
# 437       BrkSide     119000
# 438       Crawfor      90350
# 439       Edwards     110000
# 440       NridgHt     555000
# 441       Edwards     118000
# 442       BrkSide     162900
# 443       Blmngtn     172500
# 444       CollgCr     210000
# 445       Edwards     127500
# 446         NAmes     190000
# 447       Gilbert     199900
# 448        IDOTRR     119500
# 449       OldTown     120000
# 450       OldTown     110000
# 451       ClearCr     280000
# 452        Timber     204000
# 453       Somerst     210000
# 454       Mitchel     188000
# 455        NWAmes     175500
# 456       OldTown      98000
# 457       ClearCr     256000
# 458       OldTown     161000
# 459       BrkSide     110000
# 460       Somerst     263435
# 461         SWISU     155000
# 462        Sawyer      62383
# 463       Crawfor     188700
# 464       CollgCr     124000
# 465       Blmngtn     178740
# 466         NAmes     167000
# 467         NAmes     146500
# 468       NridgHt     250000
# 469       SawyerW     187000
# 470       StoneBr     212000
# 471        NWAmes     190000
# 472       Edwards     148000
# 473       NridgHt     440000
# 474       StoneBr     251000
# 475        Sawyer     132500
# 476       CollgCr     208900
# 477       NridgHt     380000
# 478       CollgCr     297000
# 479       OldTown      89471
# 480       NridgHt     326000
# 481       NridgHt     374000
# 482       OldTown     155000
# 483       Mitchel     164000
# 484        Sawyer     132500
# 485         NAmes     147000
# 486         NAmes     156000
# 487        NWAmes     175000
# 488       OldTown     160000
# 489       MeadowV      86000
# 490       MeadowV     115000
# 491         NAmes     133000
# 492       Gilbert     172785
# 493         NAmes     155000
# 494       OldTown      91300
# 495        IDOTRR      34900
# 496       NoRidge     430000
# 497       BrkSide     184000
# 498        Sawyer     130000
# 499         NAmes     120000
# ...           ...        ...
# 960       BrkSide     116500
# 961        NWAmes     272000
# 962       NPkVill     155000
# 963       CollgCr     239000
# 964        Timber     214900
# 965       Gilbert     178900
# 966       Crawfor     160000
# 967         NAmes     135000
# 968       OldTown      37900
# 969         NAmes     140000
# 970         NAmes     135000
# 971       NridgHt     173000
# 972       SawyerW      99500
# 973       Somerst     182000
# 974       BrkSide     167500
# 975       Somerst     165000
# 976       BrkSide      85500
# 977       Somerst     199900
# 978       Edwards     110000
# 979        Sawyer     139000
# 980         NAmes     178400
# 981       NoRidge     336000
# 982       Blmngtn     159895
# 983       CollgCr     255900
# 984       Mitchel     126000
# 985       Edwards     125000
# 986       OldTown     117000
# 987       NridgHt     395192
# 988        NWAmes     195000
# 989       Somerst     197000
# 990       NoRidge     348000
# 991       OldTown     168000
# 992         NAmes     187000
# 993       CollgCr     173900
# 994       NridgHt     337500
# 995       BrkSide     121600
# 996         NAmes     136500
# 997        NWAmes     185000
# 998        IDOTRR      91000
# 999       CollgCr     206000
# 1000      Edwards      82000
# 1001      OldTown      86000
# 1002      Somerst     232000
# 1003       NWAmes     136905
# 1004      Blmngtn     181000
# 1005      CollgCr     149900
# 1006        NAmes     163500
# 1007      MeadowV      88000
# 1008      Mitchel     240000
# 1009        SWISU     102000
# 1010       Sawyer     135000
# 1011      Edwards     100000
# 1012      Crawfor     165000
# 1013      OldTown      85000
# 1014        NAmes     119200
# 1015       NWAmes     227000
# 1016      CollgCr     203000
# 1017      StoneBr     187500
# 1018      Gilbert     160000
# 1019      Blmngtn     213490
# 1020      Edwards     176000
# 1021      CollgCr     194000
# 1022      OldTown      87000
# 1023      Blmngtn     191000
# 1024       Timber     287000
# 1025      CollgCr     112500
# 1026        NAmes     167500
# 1027       Timber     293077
# 1028        NAmes     105000
# 1029       BrDale     118000
# 1030        SWISU     160000
# 1031        SWISU     197000
# 1032      NoRidge     310000
# 1033      CollgCr     230000
# 1371        NAmes     165500
# 1372      CollgCr     274300
# 1373      NoRidge     466500
# 1374      Somerst     250000
# 1375       Timber     239000
# 1376        SWISU      91000
# 1377      Edwards     117000
# 1378       BrDale      83000
# 1379       Timber     167500
# 1380      Edwards      58500
# 1381        NAmes     237500
# 1382      OldTown     157000
# 1383       Sawyer     112000
# 1384      Edwards     105000
# 1385       IDOTRR     125500
# 1386       NWAmes     250000
# 1387      OldTown     136000
# 1388      Gilbert     377500
# 1389      BrkSide     131000
# 1390      CollgCr     235000
# 1391        NAmes     124000
# 1392        NAmes     123000
# 1393      OldTown     163000
# 1394      Blmngtn     246578
# 1395       Timber     281213
# 1396       Timber     160000
# 1397      BrkSide     137500
# 1398        NAmes     138000
# 1399        SWISU     137450
# 1400      BrkSide     120000
# 1401      Gilbert     193000
# 1402      CollgCr     193879
# 1403      Somerst     282922
# 1404      OldTown     105000
# 1405      Crawfor     275000
# 1406      CollgCr     133000
# 1407      Mitchel     112000
# 1408      OldTown     125500
# 1409       NWAmes     215000
# 1410      CollgCr     230000
# 1411        NAmes     140000
# 1412        NAmes      90000
# 1413      SawyerW     257000
# 1414      BrkSide     207000
# 1415      Blmngtn     175900
# 1416      OldTown     122500
# 1417      NoRidge     340000
# 1418        NAmes     124000
# 1419      Crawfor     223000
# 1420       NWAmes     179900
# 1421      NPkVill     127500
# 1422      CollgCr     136500
# 1423      Edwards     274970
# 1424        NAmes     144000
# 1425        NAmes     142000
# 1426      NoRidge     271000
# 1427        NAmes     140000
# 1428      OldTown     119000
# 1429       NWAmes     182900
# 1430      Gilbert     192140
# 1431      NPkVill     143750
# 1432      OldTown      64500
# 1433      Gilbert     186500
# 1434      Mitchel     160000
# 1435        NAmes     174000
# 1436        NAmes     120500
# 1437      NridgHt     394617
# 1438      OldTown     149700
# 1439       NWAmes     197000
# 1440      Crawfor     191000
# 1441      CollgCr     149300
# 1442      Somerst     310000
# 1443      BrkSide     121000
# 1444      CollgCr     179600
# 1445       Sawyer     129000
# 1446      Mitchel     157900
# 1447      CollgCr     240000
# 1448      Edwards     112000
# 1449      MeadowV      92000
# 1450        NAmes     136000
# 1451      Somerst     287090
# 1452      Edwards     145000
# 1453      Mitchel      84500
# 1454      Somerst     185000
# 1455      Gilbert     175000
# 1456       NWAmes     210000
# 1457      Crawfor     266500
# 1458        NAmes     142125
# 1459      Edwards     147500
#
# [1460 rows x 2 columns]
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 17:07:22.895556. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plt.figure(figsize = (12, 6))
sns.boxplot(x = 'Neighborhood', y = 'SalePrice', data = df)
xt = plt.xticks(rotation = 45)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:39:41.275945. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
plt.figure(figsize = (12, 6))
sns.countplot(x = 'Neighborhood', data = df)
xt = plt.xticks(rotation=45)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:45:09.809348. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
fig, ax = plt.subplots(2, 1, figsize = (10,6))
sns.boxplot(x = 'SaleType', y = 'SalePrice', data = df, ax = ax[0])
sns.boxplot(x = 'SaleCondition', y = 'SalePrice', data = df, ax = ax[1])
# plt.tight_layout()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:48:16.691661. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
g = sns.FacetGrid(df, col = 'YrSold', col_wrap = 3)
g.map(sns.boxplot, 'MoSold', 'SalePrice', palette='Set2', order = range(1, 13)).set(ylim = (0, 500000))
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:52:38.988572. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 8))
sns.boxplot(x = 'BldgType', y = 'SalePrice', data = df, ax = ax[0])
sns.boxplot(x = 'HouseStyle', y = 'SalePrice', data = df, ax = ax[1])
plt.tight_layout()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:55:23.629774. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 8))
sns.boxplot(x = 'Condition1', y = 'SalePrice', data = df, ax = ax[0])
sns.boxplot(x = 'Exterior1st', y = 'SalePrice', data = df, ax = ax[1])
x = plt.xticks(rotation = 45)
plt.show()
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:57:15.754851. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
fig, ax = plt.subplots(4, 1, figsize = (20, 40))
sns.boxplot('BsmtCond', 'SalePrice', data = df, ax = ax[0])
sns.boxplot('BsmtQual', 'SalePrice', data = df, ax = ax[1])
sns.boxplot('BsmtExposure', 'SalePrice', data = df, ax = ax[2])
sns.boxplot('BsmtFinType1', 'SalePrice', data = df, ax = ax[3])
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 19:58:41.970117. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
sns.violinplot('Functional', 'SalePrice', data = df)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 20:00:52.759476. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
sns.factorplot('FireplaceQu', 'SalePrice', data = df, color = 'm', 
               estimator = np.median,order = ['Ex', 'Gd', 'TA', 'Fa', 'Po'], size = 4.5, aspect = 1.35)
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 20:03:44.407175. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
pd.crosstab(df.Fireplaces, df.FireplaceQu)
# Out:
# FireplaceQu  Ex  Fa   Gd  Po   TA
# Fireplaces
# 1            19  28  324  20  259
# 2             4   4   54   0   53
# 3             1   1    2   0    1
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 20:04:17.713025. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
g = sns.FacetGrid(df, col = 'FireplaceQu', col_wrap = 3, col_order=['Ex', 'Gd', 'TA', 'Fa', 'Po'])
g.map(sns.boxplot, 'Fireplaces', 'SalePrice', order = [1, 2, 3], palette = 'Set2')
# Out:
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-10-12 20:04:37.360644. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
