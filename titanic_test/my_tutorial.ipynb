# %%
# Imports

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
path1 = '/Users/dzzxjl/PycharmProjects/kaggle/titanic_test/input/train.csv'
path2 = '/Users/dzzxjl/PycharmProjects/kaggle/titanic_test/input/test.csv'

train = pd.read_csv(path1)
test = pd.read_csv(path2)

df = train.append(test, ignore_index = True)

# %%
df[:5]
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df.describe()
# Out:
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived
# count  1309.000000  891.000000
# mean      0.498854    0.383838
# std       1.041658    0.486592
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %%
# 去除无关数据
df.drop(['PassengerId'], axis = 1)
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1279  21.0          NaN        Q    7.7500
# 1280   6.0          NaN        S   21.0750
# 1281  23.0          B24        S   93.5000
# 1282  51.0          D28        S   39.4000
# 1283  13.0          NaN        S   20.2500
# 1284  47.0          NaN        S   10.5000
# 1285  29.0          NaN        S   22.0250
# 1286  18.0          C31        S   60.0000
# 1287  24.0          NaN        Q    7.2500
# 1288  48.0          B41        C   79.2000
# 1289  22.0          NaN        S    7.7750
# 1290  31.0          NaN        Q    7.7333
# 1291  30.0           C7        S  164.8667
# 1292  38.0          NaN        S   21.0000
# 1293  22.0          NaN        C   59.4000
# 1294  17.0          NaN        S   47.1000
# 1295  43.0          D40        C   27.7208
# 1296  20.0          D38        C   13.8625
# 1297  23.0          NaN        S   10.5000
# 1298  50.0          C80        C  211.5000
# 1299   NaN          NaN        Q    7.7208
# 1300   3.0          NaN        S   13.7750
# 1301   NaN          NaN        Q    7.7500
# 1302  37.0          C78        Q   90.0000
# 1303  28.0          NaN        S    7.7750
# 1304   NaN          NaN        S    8.0500
# 1305  39.0         C105        C  108.9000
# 1306  38.5          NaN        S    7.2500
# 1307   NaN          NaN        S    8.0500
# 1308   NaN          NaN        C   22.3583
#
#                                                    Name  Parch  Pclass  Sex  \
# 0                               Braund, Mr. Owen Harris      0       3    0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1    1
# 2                                Heikkinen, Miss. Laina      0       3    1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1    1
# 4                              Allen, Mr. William Henry      0       3    0
# 5                                      Moran, Mr. James      0       3    0
# 6                               McCarthy, Mr. Timothy J      0       1    0
# 7                        Palsson, Master. Gosta Leonard      1       3    0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3    1
# 9                   Nasser, Mrs. Nicholas (Adele Achem)      0       2    1
# 10                      Sandstrom, Miss. Marguerite Rut      1       3    1
# 11                             Bonnell, Miss. Elizabeth      0       1    1
# 12                       Saundercock, Mr. William Henry      0       3    0
# 13                          Andersson, Mr. Anders Johan      5       3    0
# 14                 Vestrom, Miss. Hulda Amanda Adolfina      0       3    1
# 15                     Hewlett, Mrs. (Mary D Kingcome)       0       2    1
# 16                                 Rice, Master. Eugene      1       3    0
# 17                         Williams, Mr. Charles Eugene      0       2    0
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...      0       3    1
# 19                              Masselmani, Mrs. Fatima      0       3    1
# 20                                 Fynney, Mr. Joseph J      0       2    0
# 21                                Beesley, Mr. Lawrence      0       2    0
# 22                          McGowan, Miss. Anna "Annie"      0       3    1
# 23                         Sloper, Mr. William Thompson      0       1    0
# 24                        Palsson, Miss. Torborg Danira      1       3    1
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5       3    1
# 26                              Emir, Mr. Farred Chehab      0       3    0
# 27                       Fortune, Mr. Charles Alexander      2       1    0
# 28                        O'Dwyer, Miss. Ellen "Nellie"      0       3    1
# 29                                  Todoroff, Mr. Lalio      0       3    0
# ...                                                 ...    ...     ...  ...
# 1279                               Canavan, Mr. Patrick      0       3    0
# 1280                        Palsson, Master. Paul Folke      1       3    0
# 1281                         Payne, Mr. Vivian Ponsonby      0       1    0
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1       1    1
# 1283                      Abbott, Master. Eugene Joseph      2       3    0
# 1284                               Gilbert, Mr. William      0       2    0
# 1285                           Kink-Heilmann, Mr. Anton      1       3    0
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0       1    1
# 1287                               Colbert, Mr. Patrick      0       3    0
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1       1    1
# 1289                     Larsson-Rondberg, Mr. Edvard A      0       3    0
# 1290                           Conlon, Mr. Thomas Henry      0       3    0
# 1291                            Bonnell, Miss. Caroline      0       1    1
# 1292                                    Gale, Mr. Harry      0       2    0
# 1293                     Gibson, Miss. Dorothy Winifred      1       1    1
# 1294                             Carrau, Mr. Jose Pedro      0       1    0
# 1295                       Frauenthal, Mr. Isaac Gerald      0       1    0
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"      0       2    0
# 1297                          Ware, Mr. William Jeffery      0       2    0
# 1298                         Widener, Mr. George Dunton      1       1    0
# 1299                    Riordan, Miss. Johanna Hannah""      0       3    1
# 1300                          Peacock, Miss. Treasteall      1       3    1
# 1301                             Naughton, Miss. Hannah      0       3    1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)      0       1    1
# 1303                     Henriksson, Miss. Jenny Lovisa      0       3    1
# 1304                                 Spector, Mr. Woolf      0       3    0
# 1305                       Oliva y Ocana, Dona. Fermina      0       1    1
# 1306                       Saether, Mr. Simon Sivertsen      0       3    0
# 1307                                Ware, Mr. Frederick      0       3    0
# 1308                           Peter, Master. Michael J      1       3    0
#
#       SibSp  Survived              Ticket
# 0         1       0.0           A/5 21171
# 1         1       1.0            PC 17599
# 2         0       1.0    STON/O2. 3101282
# 3         1       1.0              113803
# 4         0       0.0              373450
# 5         0       0.0              330877
# 6         0       0.0               17463
# 7         3       0.0              349909
# 8         0       1.0              347742
# 9         1       1.0              237736
# 10        1       1.0             PP 9549
# 11        0       1.0              113783
# 12        0       0.0           A/5. 2151
# 13        1       0.0              347082
# 14        0       0.0              350406
# 15        0       1.0              248706
# 16        4       0.0              382652
# 17        0       1.0              244373
# 18        1       0.0              345763
# 19        0       1.0                2649
# 20        0       0.0              239865
# 21        0       1.0              248698
# 22        0       1.0              330923
# 23        0       1.0              113788
# 24        3       0.0              349909
# 25        1       1.0              347077
# 26        0       0.0                2631
# 27        3       0.0               19950
# 28        0       1.0              330959
# 29        0       0.0              349216
# ...     ...       ...                 ...
# 1279      0       NaN              364858
# 1280      3       NaN              349909
# 1281      0       NaN               12749
# 1282      0       NaN            PC 17592
# 1283      0       NaN           C.A. 2673
# 1284      0       NaN          C.A. 30769
# 1285      3       NaN              315153
# 1286      1       NaN               13695
# 1287      0       NaN              371109
# 1288      1       NaN               13567
# 1289      0       NaN              347065
# 1290      0       NaN               21332
# 1291      0       NaN               36928
# 1292      1       NaN               28664
# 1293      0       NaN              112378
# 1294      0       NaN              113059
# 1295      1       NaN               17765
# 1296      0       NaN       SC/PARIS 2166
# 1297      1       NaN               28666
# 1298      1       NaN              113503
# 1299      0       NaN              334915
# 1300      1       NaN  SOTON/O.Q. 3101315
# 1301      0       NaN              365237
# 1302      1       NaN               19928
# 1303      0       NaN              347086
# 1304      0       NaN           A.5. 3236
# 1305      0       NaN            PC 17758
# 1306      0       NaN  SOTON/O.Q. 3101262
# 1307      0       NaN              359309
# 1308      1       NaN                2668
#
# [1309 rows x 11 columns]

# %%
# 性别数值化
df.Sex = df.Sex.map({'male' : 0, 'female' : 1})
df[:5]
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp  Survived            Ticket
# 0       3    0      1       0.0         A/5 21171
# 1       1    1      1       1.0          PC 17599
# 2       3    1      0       1.0  STON/O2. 3101282
# 3       1    1      1       1.0            113803
# 4       3    0      0       0.0            373450

# %%
# Embarked
sns.factorplot('Embarked', 'Survived', data=df, size=4, aspect=3)

fig, (axis1, axis2, axis3) = plt.subplots(1, 3, figsize=(15, 5))

sns.countplot(x='Embarked', data=df, ax=axis1)
sns.countplot(x='Survived', hue='Embarked', data = df, ax=axis2)
# sns.countplot(x='Survived', data = df, ax=axis3)

embark_perc = df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean()
# embark_perc
sns.barplot(x='Embarked', y='Survived', data=embark_perc, order=['S', 'C', 'Q'], ax=axis3)
